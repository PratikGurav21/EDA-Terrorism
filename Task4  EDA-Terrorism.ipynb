# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv("Terrorism.csv",encoding="latin1")
# Out:
# C:\Users\LAPTECH\anaconda3\envs\rstudio\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       1.970000e+11   1970       7     2        NaN         0        NaN
# 1       1.970000e+11   1970       0     0        NaN         0        NaN
# 2       1.970010e+11   1970       1     0        NaN         0        NaN
# 3       1.970010e+11   1970       1     0        NaN         0        NaN
# 4       1.970010e+11   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
data.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
# 5  1.970010e+11   1970       1     1        NaN         0        NaN      217
# 6  1.970010e+11   1970       1     2        NaN         0        NaN      218
# 7  1.970010e+11   1970       1     2        NaN         0        NaN      217
# 8  1.970010e+11   1970       1     2        NaN         0        NaN      217
# 9  1.970010e+11   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %%
data.tail(10)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181681  2.017120e+11   2017      12    31        NaN         0        NaN
# 181682  2.017120e+11   2017      12    31        NaN         0        NaN
# 181683  2.017120e+11   2017      12    31        NaN         0        NaN
# 181684  2.017120e+11   2017      12    31        NaN         0        NaN
# 181685  2.017120e+11   2017      12    31        NaN         0        NaN
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ...  \
# 181681      160  Philippines       5  ...
# 181682       98        Italy       8  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
data.summary
# Out:
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
#                                 ...
# 181686    12/31/2017: Assailants opened fire on a Somali...
# 181687    12/31/2017: Assailants launched mortars at the...
# 181688    12/31/2017: Assailants set fire to houses in K...
# 181689    12/31/2017: Assailants threw a grenade at a Fo...
# 181690    12/31/2017: An explosive device was discovered...
# Name: summary, Length: 181691, dtype: object

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
#null velues in dataset
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
data.columns.nunique()
# Out:
# 135

# %%
data['country'].value_counts(10)
# Out:
# 95     0.135593
# 153    0.079079
# 4      0.070070
# 92     0.065826
# 45     0.045715
#          ...
# 422    0.000006
# 226    0.000006
# 428    0.000006
# 7      0.000006
# 10     0.000006
# Name: country, Length: 205, dtype: float64

# %%
data['region'].value_counts().head(10)
# Out:
# 10    50474
# 6     44974
# 3     18978
# 11    17550
# 8     16639
# 5     12485
# 2     10344
# 9      5144
# 1      3456
# 4       802
# Name: region, dtype: int64

# %%
data['provstate'].value_counts().head(10)
# Out:
# Baghdad               7645
# Northern Ireland      4498
# Unknown               4290
# Balochistan           3710
# Saladin               3411
# Al Anbar              3299
# Nineveh               3241
# Sindh                 3206
# Khyber Pakhtunkhwa    3084
# Diyala                3041
# Name: provstate, dtype: int64

# %%
data['city'].value_counts().head(10)
# Out:
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Name: city, dtype: int64

# %% [markdown]
# # Destructive Feature of data

# %%
import math
import warnings

# %%
print("Country with the most attacks:",data['country'].value_counts().idxmax())
print("City with the most attacks:",data['city'].value_counts().index[1]) #as first entry is 'unknown'
print("Region with the most attacks:",data['region'].value_counts().idxmax())
print("Year with the most attacks:",data['iyear'].value_counts().idxmax())
print("Month with the most attacks:",data['imonth'].value_counts().idxmax())
# Out:
# Country with the most attacks: 95
# City with the most attacks: Baghdad
# Region with the most attacks: 10
# Year with the most attacks: 2014
# Month with the most attacks: 5

# %%
pip install wordcloud

# %%
from wordcloud import WordCloud
from scipy import signal
cities = data.country_txt.dropna(False)
plt.subplots(figsize=(10,10))
wordcloud = WordCloud(background_color = 'white', width = 512, height = 384).generate(' '.join(cities))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()
# Out:
# C:\Users\LAPTECH\anaconda3\envs\rstudio\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of Series.dropna will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.country_txt.value_counts()[:15]
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Name: country_txt, dtype: int64

# %%
from wordcloud import WordCloud
from scipy import signal
cities = data.city.dropna(False)
plt.subplots(figsize=(10,10))
wordcloud = WordCloud(background_color = 'white', width = 512, height = 384).generate(' '.join(cities))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()
# Out:
# C:\Users\LAPTECH\anaconda3\envs\rstudio\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of Series.dropna will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from wordcloud import WordCloud
from scipy import signal
cities = data.provstate.dropna(False)
plt.subplots(figsize=(10,10))
wordcloud = WordCloud(background_color = 'white', width = 512, height = 384).generate(' '.join(cities))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()
# Out:
# C:\Users\LAPTECH\anaconda3\envs\rstudio\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of Series.dropna will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data['iyear'].value_counts(dropna = True).sort_index()
# Out:
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: iyear, dtype: int64

# %% [markdown]
# # DATA VISUALISATION

# %%
x_year = data['iyear'].unique()
y_count_years = data['iyear'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,y = y_count_years,palette = 'Blues_d')
plt.xticks(rotation = 30)
plt.xlabel('Attack Year')
plt.ylabel('Number of Attacks')
plt.title('Attack Years')
plt.show()

# %%
pd.crosstab(data.iyear, data.region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %%
plt.subplots(figsize=(15,6))
sns.barplot(data['country_txt'].value_counts()[:15].index,data['country_txt'].value_counts()[:15].values,palette='magma')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()
# Out:
# C:\Users\LAPTECH\anaconda3\envs\rstudio\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(25,5));
plt.rcParams.update({'font.size':12});
plt.xticks(rotation = 0)
plt.title('Based on Attack type')
sns.countplot(x=data.region);

# %% [markdown]
# # Conclussion

# %% [markdown]
# Most of the attacks were attacked through explosives and then through firearms.
# Attacks were more during 2014 and then in 2015. When compared to attacks from 1970 onwards, the last 6 years scored a maximum. But from 2014 onwards count started decreasing.
# Almost Every day has the same contribution but attacks were low during 31st and high during 15th and 1st.
# Iraq dominates all the countries and it has the highest number of attacks and then Pakistan, Afghanistan, and India follow it.
# The Middle East& North Africa leads 1st among all the regions and then South Asia takes 2nd place.
# For most of the attacks, the target is Private Citizens& property and the next Military leads.
# Most of the attacks were through either Bombing or Explosion.
